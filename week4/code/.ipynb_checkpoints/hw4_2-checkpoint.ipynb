# %% [markdown]
# import torch
# import torch.nn as nn
# import numpy as np
# import torch.nn.functional as F
# import matplotlib.pyplot as plt
# from load_mnist import load_mnist
#
#
#
# from torch.utils.data import DataLoader, ConcatDataset
# from collections import OrderedDict
# from functools import partial
# from adjustText import adjust_text
# import pickle
# from pathlib import Path
# from time import time

# %%
DATA_PATH = '../dataset/fashion_mnist'

# %%
class Dataset:
    def __init__(self, dataset, filter_class=None, sort=False):
        self.imgs, self.labels = load_mnist(dataset=dataset, path=DATA_PATH)
        self.imgs = self.imgs.flatten(1)
        self.labels = self.labels.long()
        
        
        self.mean = self.imgs.mean(dim=0)
        self.std = self.imgs.std(dim=0)
        # self.std, self.mean = torch.std_mean(self.images, dim=0)
    
        
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        img = (self.imgs[index] - self.mean) / (self.std + 1e-10)
        return img, self.labels[index]

# %%
def train(model, dataloader, criterion, optimizer):
    for i, (img_batch, label_batch) in enumerate(dataloader):
        optimizer.zero_grad()
        predictions = model(img_batch)
        loss = criterion(predictions, label_batch)       
        loss.backward()
        optimizer.step()

# %%
def predict(model, images):
    predictions = model(images)
    predictions = torch.argmax(predictions, dim=1)
    return predictions

def accuracy(model, dataloader):
    hits = total = 0
    for image_batch, label_batch in dataloader:
        predictions = predict(model, image_batch)
        hits += (predictions == label_batch).count_nonzero()
        total += len(image_batch)
    return hits / total 

def getGradient(model):
    gradients_of_layers = []
    for i in range(3, len(model), 2):
        gradients_of_layers.append(model[i].weight.grad.norm())
    return gradients_of_layers

# %%
# common training defs
test_dataloader = DataLoader(Dataset('testing'), batch_size=64, shuffle=False)

def run_training_method(dataloaders, epochs_per_dataloader, num_neurons, activation=nn.Sigmoid, initialization=None):
    model = FashionMNISTClassifier(num_neurons=num_neurons, activation_type=activation)    
    if initialization != None:
        model.apply(initialization)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr = 0.005)
    
    accuracies = []
    gradients = []
    
    for dataloader, num_epochs in zip(dataloaders, epochs_per_dataloader):
        for epoch in range(num_epochs):
            train(model, dataloader, criterion, optimizer)
            accuracies.append(accuracy(model, test_dataloader))
            gradients.append(getGradient(model))
            print(f"epoch {epoch}, accuracy={accuracies[-1]:.4f}")
        print("---")
        
    return accuracies, gradients

# %% [markdown]
# # (a) Train the classes separately. i.e. filter the dataset and train for five epochs on all images depicting a 0, then on all imgs depicting a 1, and so on

# %%
def plotGradients(gradients, num_neurons):
    num_layers = np.array(gradients).shape[1]
    plt.figure(figsize=(10,6))
    for i in range(num_layers): 
        gradients_layer = np.array(gradients)[:,i]
        plt.plot(gradients_layer, label="hidden layer "+str(i+1))
        plt.title(str(num_neurons))
    plt.legend()
    plt.show()

# %%
config = [[50], [50, 30], [50, 30, 30], [50, 30, 30, 30]]
# training method 1: per class training
dataloaders = [DataLoader(Dataset('training'), batch_size=64, shuffle=True)]

accuracies_diff_config = []

for num_neurons in config:
    accuracies, gradients = run_training_method(dataloaders=dataloaders, 
                                                epochs_per_dataloader=[20],
                                                num_neurons=num_neurons, 
                                                activation=nn.Sigmoid)
    accuracies_diff_config.append(accuracies)
    plotGradients(gradients, num_neurons)
    
plt.figure(figsize=(10,6))
for i in range(len(accuracies_diff_config)):
    # plot results    
    plt.plot(accuracies_diff_config[i], label=str(config[i]))
plt.legend()
plt.show()

# %% [markdown]
# # 3 with Using ReLU
#
# Here we can see that with ReLU, the norm of gradient of different layers are more similar.
# Also the model with multiple layers perform way better in accuracy with ReLU

# %%
config = [[50], [50, 30], [50, 30, 30], [50, 30, 30, 30]]
# training method 1: per class training
dataloaders = [DataLoader(Dataset('training'), batch_size=64, shuffle=True)]

accuracies_diff_config = []

for num_neurons in config:
    accuracies, gradients = run_training_method(dataloaders=dataloaders, 
                                                epochs_per_dataloader=[20],
                                                num_neurons=num_neurons, 
                                                activation=nn.ReLU)
    accuracies_diff_config.append(accuracies)
    plotGradients(gradients, num_neurons)
    
plt.figure(figsize=(10,6))
for i in range(len(accuracies_diff_config)):
    # plot results    
    plt.plot(accuracies_diff_config[i], label=str(config[i]))
plt.legend()
plt.show()

# %%
# classifier

def FashionMNISTClassifier(num_neurons, activation_type=nn.Identity):
    layers = [nn.Flatten(1)]
    last_layer_neurons = 28*28

    for i, layer_neurons in enumerate(num_neurons):
        layers.append(nn.Linear(last_layer_neurons, layer_neurons))
        layers.append(activation_type())
        last_layer_neurons = layer_neurons

    layers.append(nn.Linear(last_layer_neurons, 10))
    return nn.Sequential(*layers)

# %%
## b) Adaptive Learning Rates

# %%
import ex4 as ex
import torch
import matplotlib.pyplot as plt

# %%
train_dataloader, test_dataloader = ex.load_data()

# %%
model, metrics = ex.get_optimizer(train_dataloader, test_dataloader, 0.002, True)
# Out:
# epoch[0] acc: 14.65% train_loss: 2.3133 val_loss: 2.3147
# epoch[5] acc: 14.11% train_loss: 2.3226 val_loss: 2.3199
# epoch[10] acc: 10.00% train_loss: 2.3510 val_loss: 2.3612
# epoch[15] acc: 10.00% train_loss: 2.3611 val_loss: 2.3612
# epoch[20] acc: 10.00% train_loss: 2.3612 val_loss: 2.3612
# epoch[25] acc: 10.00% train_loss: 2.3612 val_loss: 2.3612
# epoch[30] acc: 10.00% train_loss: 2.3612 val_loss: 2.3612
# epoch[35] acc: 10.00% train_loss: 2.3611 val_loss: 2.3612
# epoch[40] acc: 10.00% train_loss: 2.3611 val_loss: 2.3612
# epoch[45] acc: 10.00% train_loss: 2.3612 val_loss: 2.3612

# %%
plt.figure(figsize=(10,6))
plt.ylim([0,1])
plt.plot(metrics['test_accuracy'], label='train', linestyle='-', marker='o')
plt.plot(metrics['train_accuracy'], label='test', linestyle='-', marker='o')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(metrics['train_loss'], label='train', linestyle='-', marker='o')
plt.plot(metrics['val_loss'], label='test', linestyle='-', marker='o')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.grid()
plt.show()

# %%
accuracy = ex.evaluate(model, test_dataloader)
print(f" Final Accuracy on CIFAR-10 Dataset : {accuracy * 100:.2f} %")
# Out:
#  Final Accuracy on CIFAR-10 Dataset : 10.00 %

# %% [markdown]
# ## comparision between SGD and ADAM Accuracy
# SGD - 46%
#
# SGD with momentum - 52%
#
# ADAM - 16 %
# It doesn't perform better than SGD without hyperparamter tunning

# %%
learn_rate =  [10e-1, 10e-2, 10e-3, 10e-4, 10e-5]
grid_search = []
for i in learn_rate:
    print(f"================ learning rate : {i} =============== ")
    model, metrics = ex.get_optimizer(train_dataloader, test_dataloader, i, True)
    grid_search.append([metrics])
# Out:
# ================ learning rate : 1.0 ===============
# epoch[0] acc: 10.16% train_loss: 2.3592 val_loss: 2.3597
# epoch[5] acc: 10.16% train_loss: 2.3593 val_loss: 2.3597
# epoch[10] acc: 10.16% train_loss: 2.3595 val_loss: 2.3597
# epoch[15] acc: 10.16% train_loss: 2.3595 val_loss: 2.3597
# epoch[20] acc: 10.16% train_loss: 2.3593 val_loss: 2.3597
# epoch[25] acc: 10.16% train_loss: 2.3594 val_loss: 2.3597
# epoch[30] acc: 10.16% train_loss: 2.3593 val_loss: 2.3597
# epoch[35] acc: 10.16% train_loss: 2.3594 val_loss: 2.3597
# epoch[40] acc: 10.16% train_loss: 2.3594 val_loss: 2.3597
# epoch[45] acc: 10.16% train_loss: 2.3595 val_loss: 2.3597
# ================ learning rate : 0.1 ===============
# epoch[0] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[5] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[10] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[15] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[20] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[25] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[30] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[35] acc: 10.00% train_loss: 2.3612 val_loss: 2.3613
# epoch[40] acc: 10.00% train_loss: 2.3611 val_loss: 2.3613
# epoch[45] acc: 10.00% train_loss: 2.3612 val_loss: 2.3613
# ================ learning rate : 0.01 ===============
# epoch[0] acc: 10.00% train_loss: 2.3612 val_loss: 2.3608
# epoch[5] acc: 10.00% train_loss: 2.3611 val_loss: 2.3608
# epoch[10] acc: 10.00% train_loss: 2.3610 val_loss: 2.3608
# epoch[15] acc: 10.00% train_loss: 2.3612 val_loss: 2.3608
# epoch[20] acc: 10.00% train_loss: 2.3612 val_loss: 2.3608
# epoch[25] acc: 10.00% train_loss: 2.3611 val_loss: 2.3608
# epoch[30] acc: 10.00% train_loss: 2.3611 val_loss: 2.3608
# epoch[35] acc: 10.00% train_loss: 2.3609 val_loss: 2.3608
# epoch[40] acc: 10.00% train_loss: 2.3612 val_loss: 2.3608
# epoch[45] acc: 10.00% train_loss: 2.3612 val_loss: 2.3608
# ================ learning rate : 0.001 ===============
# epoch[0] acc: 25.83% train_loss: 2.2043 val_loss: 2.2019
# epoch[5] acc: 21.75% train_loss: 2.2541 val_loss: 2.2437
# epoch[10] acc: 17.00% train_loss: 2.2576 val_loss: 2.2909
# epoch[15] acc: 23.64% train_loss: 2.2453 val_loss: 2.2248
# epoch[20] acc: 21.88% train_loss: 2.2426 val_loss: 2.2426
# epoch[25] acc: 22.78% train_loss: 2.2369 val_loss: 2.2336
# epoch[30] acc: 22.01% train_loss: 2.2401 val_loss: 2.2410
# epoch[35] acc: 22.65% train_loss: 2.2313 val_loss: 2.2349
# epoch[40] acc: 22.20% train_loss: 2.2348 val_loss: 2.2392
# epoch[45] acc: 22.13% train_loss: 2.2350 val_loss: 2.2400
# ================ learning rate : 0.0001 ===============
# epoch[0] acc: 42.83% train_loss: 2.0874 val_loss: 2.0306
# epoch[5] acc: 49.03% train_loss: 1.9200 val_loss: 1.9673
# epoch[10] acc: 50.59% train_loss: 1.8585 val_loss: 1.9508
# epoch[15] acc: 51.83% train_loss: 1.8117 val_loss: 1.9377
# epoch[20] acc: 52.44% train_loss: 1.7781 val_loss: 1.9329
# epoch[25] acc: 53.24% train_loss: 1.7543 val_loss: 1.9278
# epoch[30] acc: 52.89% train_loss: 1.7329 val_loss: 1.9302
# epoch[35] acc: 53.48% train_loss: 1.7192 val_loss: 1.9245
# epoch[40] acc: 53.63% train_loss: 1.7080 val_loss: 1.9229
# epoch[45] acc: 53.13% train_loss: 1.6960 val_loss: 1.9257

# %%
learn_rate =  [10e-1, 10e-2, 10e-3, 10e-4, 10e-5]
for lr, i in enumerate(grid_search):
    print(f' Learning Rate : {lr} and final acuuracy : {i[0]['train_aacuracy'][-1]:.4f}')
    plt.figure(figsize=(10,6))
    plt.ylim([0,1])
    plt.plot(i[0]['test_accuracy'], label='train', linestyle='-', marker='o')
    plt.plot(i[0]['train_accuracy'], label='test', linestyle='-', marker='o')
    plt.legend()
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.grid()
    plt.show()
    plt.figure(figsize=(10,6))
    plt.plot(i[0]['train_loss'], label='train', linestyle='-', marker='o')
    plt.plot(i[0]['val_loss'], label='test', linestyle='-', marker='o')
    plt.legend()
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.grid()
    plt.show()
